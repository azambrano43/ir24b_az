# %% [markdown]
# # Ejercicio 03: Cálculo de Relevancia y Ranking de Documentos
#
# El objetivo de este ejercicio es calcular analíticamente la relevancia de cada documento en un corpus y luego ordenar (rankear) los documentos basándonos en esa puntuación de relevancia para tres consultas específicas. Seguirás los siguientes pasos:

# %% [markdown]
# Descripción del Ejercicio
#
# 1. Procesamiento del Corpus:
#     * Leer y parsear el archivo XML proporcionado que contiene el corpus de documentos con sus metadatos (keywords, autor y fecha).
#
# 2. Procesamiento de las Consultas:
#     * Definir las consultas proporcionadas.
#     * Extraer las palabras clave de cada consulta.
#
# 3. Cálculo de Relevancia:
#     * Utilizar métricas de similitud (Similitud Coseno y Jaccard) entre la representación vectorial de los documentos y las de las consultas.
#     * Calcular la puntuación de relevancia para cada documento del corpus respecto a cada consulta.
#
# 4. Ranking de Documentos:
#     * Ordenar los documentos en función de su puntuación de relevancia de mayor a menor.
#     * Mostrar el ranking de documentos para cada consulta.

# %% [markdown]
# ### Procedimiento
# #### 1. Procesamiento del corpus

# %%
# Importar las librerías necesarias
import xml.etree.ElementTree as ET
import re
from math import sqrt
import math

# %%
# Definir las consultas
queries = {
    1: "Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios",
    2: "Actividades extracurriculares y bienestar emocional en el campus universitario",
    3: "Estrategias universitarias para reducir el estrés en estudiantes"
}

# %%
# Función para procesar el texto y extraer palabras clave
def process_text(text):
    # Convertir a minúsculas
    text = text.lower()
    
    # Reemplazar caracteres no alfanuméricos por espacios
    text = re.sub(r'[^a-záéíóúñü]+', ' ', text)
    
    # Tokenizar y eliminar palabras vacías si es necesario
    tokens = text.strip().split()
    return set(tokens)

# %%
# Paso 1: Leer y parsear el archivo XML
def parse_corpus(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    corpus = {}
    for doc in root.findall('document'):
        doc_id = int(doc.get('id'))
        title = doc.find('title').text
        keywords = doc.find('keywords').text
        author = doc.find('author').text
        date = doc.find('date').text
        
        # Procesar las palabras clave
        keyword_set = process_text(keywords)
        corpus[doc_id] = {
            'title': title,
            'keywords': keyword_set,
            'author': author,
            'date': date
        }
    return corpus

# %%
# Ejecutar la función con el archivo proporcionado
corpus = parse_corpus('../data/03ranking_corpus.xml')
for doc_id, doc_data in corpus.items():
    print(f"Documento ID: {doc_id}")
    for key, value in doc_data.items():
        print(f"  {key.capitalize()}: {value}")
    print("-" * 40)
# Out:
# Documento ID: 1
#   Title: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#   Keywords: {'médica', 'salud', 'telemedicina', 'tratamiento', 'tecnología', 'crónica'}
#   Author: Dr. Juan Pérez
#   Date: 2023-01-15
# ----------------------------------------
# Documento ID: 2
#   Title: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#   Keywords: {'mental', 'académico', 'nutrición', 'rendimiento', 'salud', 'estudiantes'}
#   Author: Dra. María López
#   Date: 2023-02-10
# ----------------------------------------
# Documento ID: 3
#   Title: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#   Keywords: {'relaciones', 'campus', 'sociales', 'estudiantil', 'amistad', 'bienestar'}
#   Author: Miguel Rodríguez
#   Date: 2023-03-05
# ----------------------------------------
# Documento ID: 4
#   Title: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#   Keywords: {'universitarias', 'recursos', 'investigación', 'academia', 'bibliotecas'}
#   Author: Lucía Martínez
#   Date: 2023-04-20
# ----------------------------------------
# Documento ID: 5
#   Title: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#   Keywords: {'campus', 'verdes', 'universitario', 'espacios', 'concentración', 'estrés'}
#   Author: Carlos Fernández
#   Date: 2023-05-15
# ----------------------------------------
# Documento ID: 6
#   Title: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#   Keywords: {'estudiantes', 'universitaria', 'cultura', 'saludables', 'hábitos', 'bienestar'}
#   Author: Ana Sánchez
#   Date: 2023-06-10
# ----------------------------------------
# Documento ID: 7
#   Title: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#   Keywords: {'universitarios', 'mental', 'académico', 'rendimiento', 'salud', 'sueño'}
#   Author: Javier Torres
#   Date: 2023-07-25
# ----------------------------------------
# Documento ID: 8
#   Title: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#   Keywords: {'social', 'familiar', 'estudiantes', 'emocional', 'apoyo', 'bienestar'}
#   Author: Laura Gómez
#   Date: 2023-08-30
# ----------------------------------------
# Documento ID: 9
#   Title: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#   Keywords: {'lectura', 'jóvenes', 'desarrollo', 'adultos', 'de', 'cognitivo', 'hábitos'}
#   Author: Fernando Ruiz
#   Date: 2023-09-18
# ----------------------------------------
# Documento ID: 10
#   Title: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#   Keywords: {'jóvenes', 'avances', 'médica', 'tecnológicos', 'preventiva', 'medicina', 'tecnología'}
#   Author: Elena Navarro
#   Date: 2023-10-05
# ----------------------------------------
# Documento ID: 11
#   Title: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#   Keywords: {'universitarios', 'académico', 'salud', 'estudiantes', 'ejercicio', 'estrés'}
#   Author: Diego Castro
#   Date: 2023-11-12
# ----------------------------------------
# Documento ID: 12
#   Title: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#   Keywords: {'mindfulness', 'universitarios', 'meditación', 'estudiantes', 'ansiedad'}
#   Author: Sofía Vega
#   Date: 2023-12-01
# ----------------------------------------
# Documento ID: 13
#   Title: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#   Keywords: {'universitarios', 'mental', 'psicológico', 'salud', 'estudiantes', 'de', 'grupos', 'estudio', 'apoyo'}
#   Author: Marcos Ortiz
#   Date: 2024-01-10
# ----------------------------------------
# Documento ID: 14
#   Title: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#   Keywords: {'universitarios', 'desempeño', 'mental', 'académico', 'salud', 'estudiantes', 'servicios'}
#   Author: Paula Morales
#   Date: 2024-02-15
# ----------------------------------------
# Documento ID: 15
#   Title: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#   Keywords: {'social', 'estudiantes', 'extracurriculares', 'emocional', 'actividades', 'bienestar'}
#   Author: José Herrera
#   Date: 2024-03-05
# ----------------------------------------
# Documento ID: 16
#   Title: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#   Keywords: {'educación', 'competencias', 'desarrollo', 'de', 'tecnológicas', 'laboratorios', 'innovación'}
#   Author: Andrea Díaz
#   Date: 2024-04-20
# ----------------------------------------
# Documento ID: 17
#   Title: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#   Keywords: {'tendencias', 'colaboración', 'campus', 'de', 'diseño', 'interacción'}
#   Author: Sergio Muñoz
#   Date: 2024-05-15
# ----------------------------------------
# Documento ID: 18
#   Title: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#   Keywords: {'académico', 'comparación', 'rendimiento', 'estudiantes', 'que', 'trabajan', 'bienestar'}
#   Author: Isabel Flores
#   Date: 2024-06-10
# ----------------------------------------
# Documento ID: 19
#   Title: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#   Keywords: {'agotamiento', 'prevención', 'universitarios', 'académico', 'de', 'estudiantes', 'factores', 'riesgo'}
#   Author: Ricardo Ramos
#   Date: 2024-07-25
# ----------------------------------------
# Documento ID: 20
#   Title: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#   Keywords: {'redes', 'calidad', 'sueño', 'estudiantes', 'sociales', 'tecnología', 'del'}
#   Author: Valeria Castillo
#   Date: 2024-08-30
# ----------------------------------------
# Documento ID: 21
#   Title: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#   Keywords: {'universitarios', 'impacto', 'ambiental', 'verdes', 'edificios', 'sostenibilidad', 'tecnologías'}
#   Author: Daniel Medina
#   Date: 2024-09-18
# ----------------------------------------
# Documento ID: 22
#   Title: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#   Keywords: {'movilidad', 'transporte', 'compartidas', 'bicicletas', 'sostenible', 'universidades'}
#   Author: Patricia Reyes
#   Date: 2024-10-05
# ----------------------------------------
# Documento ID: 23
#   Title: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#   Keywords: {'carga', 'académica', 'salud', 'estudiantes', 'universitario', 'emocional', 'apoyo'}
#   Author: Gonzalo Soto
#   Date: 2024-11-12
# ----------------------------------------
# Documento ID: 24
#   Title: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#   Keywords: {'vida', 'académica', 'social', 'estudiantes', 'equilibrio', 'estrategias'}
#   Author: Camila Aguilar
#   Date: 2024-12-01
# ----------------------------------------
# Documento ID: 25
#   Title: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#   Keywords: {'vida', 'psicológico', 'universitaria', 'actividades', 'artísticas', 'creatividad', 'bienestar'}
#   Author: Adrián Vargas
#   Date: 2025-01-10
# ----------------------------------------
# Documento ID: 26
#   Title: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#   Keywords: {'universidades', 'beneficios', 'programas', 'de', 'estudiantes', 'retención', 'becas'}
#   Author: Teresa Romero
#   Date: 2025-02-15
# ----------------------------------------
# Documento ID: 27
#   Title: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#   Keywords: {'actividad', 'física', 'integración', 'deportes', 'social', 'estudiantes'}
#   Author: Alberto Peña
#   Date: 2025-03-05
# ----------------------------------------
# Documento ID: 28
#   Title: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#   Keywords: {'universidad', 'estrés', 'de', 'eventos', 'del', 'talleres', 'reducción', 'bienestar'}
#   Author: Silvia Campos
#   Date: 2025-04-20
# ----------------------------------------
# Documento ID: 29
#   Title: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#   Keywords: {'en', 'rendimiento', 'de', 'sueño', 'análisis', 'estudiantes', 'exámenes', 'hábitos'}
#   Author: Óscar Luna
#   Date: 2025-05-15
# ----------------------------------------
# Documento ID: 30
#   Title: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#   Keywords: {'comunidades', 'médicos', 'inteligencia', 'servicios', 'artificial', 'tecnología', 'remotas'}
#   Author: María Paredes
#   Date: 2025-06-10
# ----------------------------------------

# %% [markdown]
# ### 2. Procesamiento de las Consultas

# %%
# 2.1 Definir las consultas proporcionadas
# Inicializa un diccionario vacío para almacenar solo el texto de cada consulta proporcionada
query_texts = {}

# Itera sobre cada consulta en el diccionario 'queries', donde cada clave (qid) es un identificador de consulta
for qid, query in queries.items():
    # Almacena el texto de la consulta en el diccionario 'query_texts' usando su identificador como clave
    query_texts[qid] = query

# Imprime el resultado que contiene todas las consultas proporcionadas, sin procesar
query_texts
# Out:
# {1: 'Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios',
#  2: 'Actividades extracurriculares y bienestar emocional en el campus universitario',
#  3: 'Estrategias universitarias para reducir el estrés en estudiantes'}

# %%
# 2.2 Extraer las palabras clave de cada consulta
# Inicializa un diccionario vacío para almacenar las palabras clave de cada consulta
query_keywords = {}

# Itera a través de cada consulta en el diccionario 'queries' usando el identificador y el texto de la consulta
for qid, query in queries.items():
    
    # Llama a la función 'process_text' para extraer las palabras clave del texto de la consulta
    keyword_set = process_text(query)
    
    # Almacena tanto el texto original de la consulta como su conjunto de palabras clave en el diccionario 'query_keywords'
    query_keywords[qid] = {
        'text': query,
        'keywords': keyword_set
    }

# Imprime los resultados del diccionario 'query_keywords', que contiene cada consulta y sus palabras clave extraídas
query_keywords
# Out:
# {1: {'text': 'Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios',
#   'keywords': {'académico',
#    'de',
#    'el',
#    'en',
#    'estudiantes',
#    'impacto',
#    'la',
#    'los',
#    'mental',
#    'rendimiento',
#    'salud',
#    'universitarios'}},
#  2: {'text': 'Actividades extracurriculares y bienestar emocional en el campus universitario',
#   'keywords': {'actividades',
#    'bienestar',
#    'campus',
#    'el',
#    'emocional',
#    'en',
#    'extracurriculares',
#    'universitario',
#    'y'}},
#  3: {'text': 'Estrategias universitarias para reducir el estrés en estudiantes',
#   'keywords': {'el',
#    'en',
#    'estrategias',
#    'estrés',
#    'estudiantes',
#    'para',
#    'reducir',
#    'universitarias'}}}

# %% [markdown]
# ### 3. Cálculo de Relevancia

# %%
# Función para calcular la similitud de coseno entre dos conjuntos de palabras
def cosine_similarity(set1, set2):
    # Crear el conjunto de palabras únicas a partir de la unión de ambos conjuntos
    words = list(set1.union(set2))
    
    # Crear los vectores de frecuencia binarios para cada conjunto
    vec1 = [1 if word in set1 else 0 for word in words]
    vec2 = [1 if word in set2 else 0 for word in words]

    # Calcular el producto punto y las magnitudes de los vectores
    dot_product = sum(v1 * v2 for v1, v2 in zip(vec1, vec2))
    magnitude1 = math.sqrt(sum(v ** 2 for v in vec1))
    magnitude2 = math.sqrt(sum(v ** 2 for v in vec2))
    
    # Evitar la división por cero, en caso de que una magnitud sea cero
    if magnitude1 == 0 or magnitude2 == 0:
        return 0.0
    
    # Retorna la similitud de coseno entre los dos conjuntos
    return dot_product / (magnitude1 * magnitude2)

# Función para calcular la similitud de Jaccard entre dos conjuntos de palabras
def jaccard_similarity(set1, set2):
    # Calcular la intersección y la unión de los dos conjuntos
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    
    # Evitar la división por cero en caso de que la unión sea vacía
    if not union:
        return 0.0
    
    # Retorna la similitud de Jaccard como el tamaño de la intersección dividido por el tamaño de la unión
    return len(intersection) / len(union)

# %%
# Función para calcular la relevancia de cada documento respecto a cada consulta
def calculate_relevance(corpus, query_keywords):
    # Inicializa un diccionario para almacenar la relevancia de cada documento respecto a cada consulta
    relevance = {}
    
    # Itera sobre cada consulta en 'query_keywords'
    for qid, query_data in query_keywords.items():
        relevance[qid] = {}
        query_kw = query_data['keywords']
        
        # Itera sobre cada documento en el corpus
        for doc_id, doc_data in corpus.items():
            doc_kw = doc_data['keywords']

            # Calcula la similitud de coseno y Jaccard entre las palabras clave de la consulta y el documento
            cos_sim = cosine_similarity(query_kw, doc_kw)
            jac_sim = jaccard_similarity(query_kw, doc_kw)

            # Almacena las similitudes en el diccionario de relevancia para cada consulta y documento
            relevance[qid][doc_id] = {
                'cosine_similarity': cos_sim,
                'jaccard_similarity': jac_sim
            }

    # Retorna el diccionario de relevancia que contiene las puntuaciones de similitud para cada consulta y documento
    return relevance

# Calcula la relevancia de cada documento en el corpus respecto a cada consulta y almacena los resultados
relevance = calculate_relevance(corpus, query_keywords)

# # Imprime el diccionario 'relevance', que contiene las puntuaciones de relevancia calculadas para cada consulta y documento
# relevance

# %%
# Formatear los resultados de relevancia para una mejor visualización
def print_relevance_results(relevance):
    for qid, docs in relevance.items():
        print(f"Resultados para la Consulta {qid}:\n")
        for doc_id, scores in docs.items():
            cos_sim = round(scores['cosine_similarity'], 10)
            jac_sim = round(scores['jaccard_similarity'], 10)
            print(f"  Documento {doc_id}:")
            print(f"    - Similitud Coseno: {cos_sim}")
            print(f"    - Similitud Jaccard: {jac_sim}")
        print("\n" + "-" * 40 + "\n")  # Separador entre consultas

# Llamada a la función para imprimir los resultados formateados
print_relevance_results(relevance)
# Out:
# Resultados para la Consulta 1:
#
#   Documento 1:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 2:
#     - Similitud Coseno: 0.589255651
#     - Similitud Jaccard: 0.3846153846
#   Documento 3:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 4:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 5:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 6:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 7:
#     - Similitud Coseno: 0.589255651
#     - Similitud Jaccard: 0.3846153846
#   Documento 8:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 9:
#     - Similitud Coseno: 0.1091089451
#     - Similitud Jaccard: 0.0555555556
#   Documento 10:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 11:
#     - Similitud Coseno: 0.4714045208
#     - Similitud Jaccard: 0.2857142857
#   Documento 12:
#     - Similitud Coseno: 0.2581988897
#     - Similitud Jaccard: 0.1333333333
#   Documento 13:
#     - Similitud Coseno: 0.4811252243
#     - Similitud Jaccard: 0.3125
#   Documento 14:
#     - Similitud Coseno: 0.5455447256
#     - Similitud Jaccard: 0.3571428571
#   Documento 15:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 16:
#     - Similitud Coseno: 0.1091089451
#     - Similitud Jaccard: 0.0555555556
#   Documento 17:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 18:
#     - Similitud Coseno: 0.3273268354
#     - Similitud Jaccard: 0.1875
#   Documento 19:
#     - Similitud Coseno: 0.4082482905
#     - Similitud Jaccard: 0.25
#   Documento 20:
#     - Similitud Coseno: 0.1091089451
#     - Similitud Jaccard: 0.0555555556
#   Documento 21:
#     - Similitud Coseno: 0.2182178902
#     - Similitud Jaccard: 0.1176470588
#   Documento 22:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 23:
#     - Similitud Coseno: 0.2182178902
#     - Similitud Jaccard: 0.1176470588
#   Documento 24:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 25:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 26:
#     - Similitud Coseno: 0.2182178902
#     - Similitud Jaccard: 0.1176470588
#   Documento 27:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0588235294
#   Documento 28:
#     - Similitud Coseno: 0.1020620726
#     - Similitud Jaccard: 0.0526315789
#   Documento 29:
#     - Similitud Coseno: 0.4082482905
#     - Similitud Jaccard: 0.25
#   Documento 30:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#
# ----------------------------------------
#
# Resultados para la Consulta 2:
#
#   Documento 1:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 2:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 3:
#     - Similitud Coseno: 0.272165527
#     - Similitud Jaccard: 0.1538461538
#   Documento 4:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 5:
#     - Similitud Coseno: 0.272165527
#     - Similitud Jaccard: 0.1538461538
#   Documento 6:
#     - Similitud Coseno: 0.1360827635
#     - Similitud Jaccard: 0.0714285714
#   Documento 7:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 8:
#     - Similitud Coseno: 0.272165527
#     - Similitud Jaccard: 0.1538461538
#   Documento 9:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 10:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 11:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 12:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 13:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 14:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 15:
#     - Similitud Coseno: 0.544331054
#     - Similitud Jaccard: 0.3636363636
#   Documento 16:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 17:
#     - Similitud Coseno: 0.1360827635
#     - Similitud Jaccard: 0.0714285714
#   Documento 18:
#     - Similitud Coseno: 0.1259881577
#     - Similitud Jaccard: 0.0666666667
#   Documento 19:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 20:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 21:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 22:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 23:
#     - Similitud Coseno: 0.2519763153
#     - Similitud Jaccard: 0.1428571429
#   Documento 24:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 25:
#     - Similitud Coseno: 0.2519763153
#     - Similitud Jaccard: 0.1428571429
#   Documento 26:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 27:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 28:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0625
#   Documento 29:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0625
#   Documento 30:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#
# ----------------------------------------
#
# Resultados para la Consulta 3:
#
#   Documento 1:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 2:
#     - Similitud Coseno: 0.1443375673
#     - Similitud Jaccard: 0.0769230769
#   Documento 3:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 4:
#     - Similitud Coseno: 0.158113883
#     - Similitud Jaccard: 0.0833333333
#   Documento 5:
#     - Similitud Coseno: 0.1443375673
#     - Similitud Jaccard: 0.0769230769
#   Documento 6:
#     - Similitud Coseno: 0.1443375673
#     - Similitud Jaccard: 0.0769230769
#   Documento 7:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 8:
#     - Similitud Coseno: 0.1443375673
#     - Similitud Jaccard: 0.0769230769
#   Documento 9:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 10:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 11:
#     - Similitud Coseno: 0.2886751346
#     - Similitud Jaccard: 0.1666666667
#   Documento 12:
#     - Similitud Coseno: 0.158113883
#     - Similitud Jaccard: 0.0833333333
#   Documento 13:
#     - Similitud Coseno: 0.1178511302
#     - Similitud Jaccard: 0.0625
#   Documento 14:
#     - Similitud Coseno: 0.133630621
#     - Similitud Jaccard: 0.0714285714
#   Documento 15:
#     - Similitud Coseno: 0.1443375673
#     - Similitud Jaccard: 0.0769230769
#   Documento 16:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 17:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 18:
#     - Similitud Coseno: 0.133630621
#     - Similitud Jaccard: 0.0714285714
#   Documento 19:
#     - Similitud Coseno: 0.125
#     - Similitud Jaccard: 0.0666666667
#   Documento 20:
#     - Similitud Coseno: 0.133630621
#     - Similitud Jaccard: 0.0714285714
#   Documento 21:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 22:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 23:
#     - Similitud Coseno: 0.133630621
#     - Similitud Jaccard: 0.0714285714
#   Documento 24:
#     - Similitud Coseno: 0.2886751346
#     - Similitud Jaccard: 0.1666666667
#   Documento 25:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#   Documento 26:
#     - Similitud Coseno: 0.133630621
#     - Similitud Jaccard: 0.0714285714
#   Documento 27:
#     - Similitud Coseno: 0.1443375673
#     - Similitud Jaccard: 0.0769230769
#   Documento 28:
#     - Similitud Coseno: 0.125
#     - Similitud Jaccard: 0.0666666667
#   Documento 29:
#     - Similitud Coseno: 0.25
#     - Similitud Jaccard: 0.1428571429
#   Documento 30:
#     - Similitud Coseno: 0.0
#     - Similitud Jaccard: 0.0
#
# ----------------------------------------

# %% [markdown]
# ### 4. Ranking de Documentos

# %%
# Función para ordenar los documentos en función de su puntuación de relevancia
def rank_results(relevance):
    rankings = {}  # Diccionario para almacenar el ranking de documentos para cada consulta

    for qid, scores in relevance.items():  # Iterar sobre cada consulta y sus puntajes de relevancia
        # Ordenar los documentos por similitud coseno en orden descendente
        ranked_docs = sorted(scores.items(), key=lambda x: x[1]['cosine_similarity'], reverse=True)
        rankings[qid] = ranked_docs  # Guardar el ranking ordenado de documentos para la consulta actual

    return rankings  # Retornar el diccionario con los rankings para todas las consultas

# %%
# Llamar a la función para obtener los documentos ordenados por relevancia
ranked_documents = rank_results(relevance)

# %%
# Mostrar el ranking de documentos para cada consulta
for qid, ranked_docs in ranked_documents.items():
    print(f"Consulta: {queries[qid]}")  # Imprimir la consulta actual
    for rank, (doc_id, scores) in enumerate(ranked_docs, 1):  # Enumerar y mostrar el ranking
        # Imprimir el ranking y título del documento
        print(f"  Rango {rank}: Documento {doc_id} ({corpus[doc_id]['title']})")
    print("\n" + "-" * 40 + "\n")  # Separador entre consultas para mayor legibilidad
# Out:
# Consulta: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
#   Rango 1: Documento 2 (Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.)
#   Rango 2: Documento 7 (La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.)
#   Rango 3: Documento 14 (Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.)
#   Rango 4: Documento 13 (Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.)
#   Rango 5: Documento 11 (Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.)
#   Rango 6: Documento 19 (Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.)
#   Rango 7: Documento 29 (Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.)
#   Rango 8: Documento 18 (Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.)
#   Rango 9: Documento 12 (El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.)
#   Rango 10: Documento 21 (Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.)
#   Rango 11: Documento 23 (Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.)
#   Rango 12: Documento 26 (Los beneficios de los programas de becas para la retención de estudiantes en universidades.)
#   Rango 13: Documento 1 (El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.)
#   Rango 14: Documento 6 (La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.)
#   Rango 15: Documento 8 (La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.)
#   Rango 16: Documento 15 (Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.)
#   Rango 17: Documento 17 (Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.)
#   Rango 18: Documento 24 (Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.)
#   Rango 19: Documento 27 (El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.)
#   Rango 20: Documento 9 (El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.)
#   Rango 21: Documento 16 (El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.)
#   Rango 22: Documento 20 (El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.)
#   Rango 23: Documento 28 (Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.)
#   Rango 24: Documento 3 (Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.)
#   Rango 25: Documento 4 (El rol de las bibliotecas universitarias en el fomento de la investigación académica.)
#   Rango 26: Documento 5 (Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.)
#   Rango 27: Documento 10 (Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.)
#   Rango 28: Documento 22 (Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.)
#   Rango 29: Documento 25 (La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.)
#   Rango 30: Documento 30 (Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.)
#
# ----------------------------------------
#
# Consulta: Actividades extracurriculares y bienestar emocional en el campus universitario
#   Rango 1: Documento 15 (Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.)
#   Rango 2: Documento 3 (Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.)
#   Rango 3: Documento 5 (Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.)
#   Rango 4: Documento 8 (La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.)
#   Rango 5: Documento 23 (Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.)
#   Rango 6: Documento 25 (La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.)
#   Rango 7: Documento 6 (La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.)
#   Rango 8: Documento 17 (Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.)
#   Rango 9: Documento 18 (Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.)
#   Rango 10: Documento 28 (Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.)
#   Rango 11: Documento 29 (Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.)
#   Rango 12: Documento 1 (El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.)
#   Rango 13: Documento 2 (Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.)
#   Rango 14: Documento 4 (El rol de las bibliotecas universitarias en el fomento de la investigación académica.)
#   Rango 15: Documento 7 (La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.)
#   Rango 16: Documento 9 (El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.)
#   Rango 17: Documento 10 (Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.)
#   Rango 18: Documento 11 (Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.)
#   Rango 19: Documento 12 (El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.)
#   Rango 20: Documento 13 (Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.)
#   Rango 21: Documento 14 (Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.)
#   Rango 22: Documento 16 (El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.)
#   Rango 23: Documento 19 (Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.)
#   Rango 24: Documento 20 (El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.)
#   Rango 25: Documento 21 (Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.)
#   Rango 26: Documento 22 (Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.)
#   Rango 27: Documento 24 (Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.)
#   Rango 28: Documento 26 (Los beneficios de los programas de becas para la retención de estudiantes en universidades.)
#   Rango 29: Documento 27 (El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.)
#   Rango 30: Documento 30 (Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.)
#
# ----------------------------------------
#
# Consulta: Estrategias universitarias para reducir el estrés en estudiantes
#   Rango 1: Documento 11 (Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.)
#   Rango 2: Documento 24 (Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.)
#   Rango 3: Documento 29 (Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.)
#   Rango 4: Documento 4 (El rol de las bibliotecas universitarias en el fomento de la investigación académica.)
#   Rango 5: Documento 12 (El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.)
#   Rango 6: Documento 2 (Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.)
#   Rango 7: Documento 5 (Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.)
#   Rango 8: Documento 6 (La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.)
#   Rango 9: Documento 8 (La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.)
#   Rango 10: Documento 15 (Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.)
#   Rango 11: Documento 27 (El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.)
#   Rango 12: Documento 14 (Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.)
#   Rango 13: Documento 18 (Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.)
#   Rango 14: Documento 20 (El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.)
#   Rango 15: Documento 23 (Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.)
#   Rango 16: Documento 26 (Los beneficios de los programas de becas para la retención de estudiantes en universidades.)
#   Rango 17: Documento 19 (Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.)
#   Rango 18: Documento 28 (Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.)
#   Rango 19: Documento 13 (Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.)
#   Rango 20: Documento 1 (El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.)
#   Rango 21: Documento 3 (Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.)
#   Rango 22: Documento 7 (La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.)
#   Rango 23: Documento 9 (El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.)
#   Rango 24: Documento 10 (Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.)
#   Rango 25: Documento 16 (El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.)
#   Rango 26: Documento 17 (Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.)
#   Rango 27: Documento 21 (Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.)
#   Rango 28: Documento 22 (Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.)
#   Rango 29: Documento 25 (La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.)
#   Rango 30: Documento 30 (Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.)
#
# ----------------------------------------
